# %%
from simcon import *

# %%
## Problems from Korn and Korn, 
## https://archive.org/details/electronicanalog00korn/page/n77
## 1) Dynamic vibration absorber

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
