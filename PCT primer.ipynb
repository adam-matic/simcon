# %% [raw]
#   Introduction to perceptual control theory, Part I
#
# This tutorial series introduces the principles of perceptual control
# theory, or PCT, through simulations on an analogue computer. The analogue
# computer runs on a PC; the program for running it, SIMCON 4.5, was
# written by Wolfgang Zocher of Hannover, Germany, and thanks to his
# generosity is available as freeware.
#
# (ported to python by A.Matic, 2019)

# %% [raw]
#                         Introduction: PCT
#
# Perceptual control theory (PCT) is a theory of human and animal behavior
# based on engineering control theory. Engineering control theory, when
# developed during the 1930s, arose from an attempt to build machines that
# could duplicate human behavior in tasks that could not be done by
# ordinary machines because the actions required at any moment could not
# be predicted.
#
# These were control tasks. They required the human being to act on the
# environment in such a way that some aspect of the environment (like
# temperature or speed) was held constant, or was varied in some desired
# arbitrary way, despite unpredictable disturbances whose causes could
# neither be anticipated nor sensed. This kind of behavior differed from
# the kind studied in the conventional sciences of behavior. Instead of the
# behavior itself, the actions of the person, being generated in some
# particular pattern, affected something else in the environment and that
# something else was controlled. Hence we call that "something else" a
# controlled variable: variable because it is inherently capable of
# variation, and controlled because the person acts on it to prevent
# unwanted variations. Because controlled variables are in general subject
# to unpredictable disturbances, the actions required to control them are
# also unpredictable. The organization called a control system can produce
# actions in just that way.
#
# A familiar example can be found in steering a car. The actions of the
# driver consist of turning the steering wheel by applying forces to it
# with the arms and hands. These actions, in the terms of conventional
# sciences of life, are the "behavior" of the driver. But these actions
# affect something outside the driver, in the environment: the position of
# the car on the road. As the car moves along, it is disturbed in many
# ways. The roadbed has bumps in it and it tilts by different amounts.
# Winds push the car to one side or another. The car itself might have
# small defects like a soft tire or a tight wheel bearing, or its wheels
# might be slightly out of alignment. All these sources of disturbance act
# at the same time and tend to make the car veer to one side or the other
# by varying and unpredictable amounts. There is no way to sort out one
# cause of a disturbance from another; only the sum of all the varying
# disturbing influences causes the car to change course.
#
# One of the disturbances is the angle of the front wheels of the car. That
# one disturbance, out of all those present, is affected by the driver's
# steering actions. When we see a car going in a straight line down the
# proper lane of a road, we can therefore deduce a simple fact: the
# disturbance of the car caused by the driver's steering actions must be
# equal and opposite at all times to the sum of all the other disturbing
# effects on the car's path. If for a moment the sum of those other effects
# is zero, the driver's steering effort must be zero at that moment. If the
# other effects are nonzero, the driver's effort is also nonzero by the
# same amount and in the opposite direction, as translated into an angle
# of the front wheels and thus a force on the car.
#
# In this example, the controlled variable is the position of the car on
# the road. We say it is controlled by the driver because the driver's
# steering efforts prevent all the other disturbances from having their
# normal effects. But there is more to control than that. Not only can the
# driver cancel out disturbances of the controlled variable, but the driver
# can arbitrarily decide to bring the car to a new position on the road and
# hold it there, or even to make the car follow a particular desired
# pattern of side-to-side movements, still while preventing the other
# disturbances from causing any unwanted deviations from the desired path.
# When control is happening, the controlled variable becomes subject to the
# driver's intentions, and ceases to be subject to the environmental
# influences that normally affect it. If it were not for control, driving
# a car would be a dangerous business.
#
# PCT is a theory that explains how a human being or an animal could
# possibly act in such a way as to control something in its environment.
# The question of how control works takes us along a path that deviates
# more and more from conventional concepts of behavioral organization. We
# are forced to ask how the driver knows when to respond and when not to
# respond; we must ask how the driver knows when the car is in the right
# place, and how that "mental" knowledge can have a physical effect on the
# driver's actions. We have to face questions that conventional sciences
# long ago dismissed as unscientific: what is a desire, or an intention,
# or a purpose? Only in very recent times have these questions reappeared
# in polite scientific discourse -- yet the answer to them has been
# available for 60 years. The answer is to be found in control theory, and
# more explictly in PCT, which is an adaptation of engineering control
# theory to the particular relationship that holds between any organism and
# its environment.
#
# We will reach the basic explanation of control behavior quite soon, but
# first we must lay some groundwork. Few readers will be familiar with
# analog computers and they way they are used to simulate physical systems.
# We must introduce some basics first, sticking to those that we need here.
# We'll begin by seeing how we simulate the environment of a control
# system.
#
#                  Simulating the environment
#
# This is an ambitious concept, considering what exists in "the
# environment." We are not, however, going to simulate everything since the
# Big Bang, but only the aspect of the environment with which a control
# system is immediately interacting. This boils down to simulating a
# controlled variable and a disturbing variable that acts on the controlled
# variable. The controlled variable won't really be controlled until we add
# the control system.
#
# Please be patient with the pace of the following development. The purpose
# is mostly to show by example how SIMCON is used, and how analog computer
# setups ("programs") are generated and their results plotted and
# interpreted.
#
# Just to tie this to a physical situation, let's suppose that the
# controlled variable is something about a bright yellow rubber duck
# costing $1.79 floating in the middle of a backyard swimming pool's
# swimming pool. The duck bobs up and down a little; its feet are 4.5 cm.
# below the surface of the water. There are obviously many things about
# this duck that might be of interest, but to find a controlled variable
# we must find something about that duck that can VARY. We will pick just
# one possible variable: its velocity. Not only that, we will narrow the
# variable even further, to its velocity in the east-west direction,
# ignoring any north-south or up-down component of velocity. We will call
# this velocity "vel". That is the only aspect of the yellow rubber duck
# that is of any interest now, so we can represent the whole state of the
# duck with a single number: vel. Right at the moment vel = 0. That means
# that the duck is not moving in the east-west direction.
#
# Now for the disturbing variable. The disturbing variable must be
# definable independently, without knowing what it is disturbing. The same
# disturbing variable might disturb a number of other physical variables
# in different ways depending on its physical connection to them. Our
# disturbing influence for present purposes is a 12-inch fan costing
# $12.50, with a variable-speed control, plugged into an extension cord
# running from the house into the back yard. Of all the aspects of the fan
# we might be interested in, the variable we will pick here will be the
# rotational speed of its blades. That is the disturbing variable, to which
# we refer by the symbol d. If d = 0, the blades are stationary. The larger
# d is, the faster the blades are spinning. If d goes negative, the blades
# are spinning the other way.
#
# So we have picked out of the mass of details about the $1.79 rubber duck
# and the $12.50 fan just two variables: vel, the duck's velocity in the
# east-west direction, and d, the speed of rotation of the fan blades. From
# now on, vel represents the duck and d represents the fan. This is the
# first step in any simulation of a real system: going from a vague
# description of irrelevant things in the environment to a specification
# of variables. The trick is to pick variables that tell us something
# useful.
#
# We set the fan up east of the duck and turn it on, aiming it at the duck.
# As we increase the setting of the fan's speed control, the blades spin
# faster (d increases) and the air velocity near the duck increases. This
# causes a force on the duck, which begins to move downwind. It takes the
# duck a little while to reach its final velocity, a few tenths of a
# second. Then it moves at a steady velocity at which the water drag equals
# the force from the wind on it. If we turn up the fan's speed, the duck
# moves through the water faster. So vel depends on d. Now the question is,
# HOW does vel depend on d?
#
# With hours of rigorous experimentation, we arrive at some very
# encouraging results: the duck's velocity is proportional to the speed of
# the fan blades! This means we can use a simple equation to deduce the
# speed of the duck from knowing the speed of the fan blades, assuming
# nothing else is pushing on the duck. At 100 RPM the duck moves 10 mm per
# second; at 1000 RPM the duck moves 100 mm per second. So if we measure
# d (the fan blade speed) in RPM and vel (the duck's westerly speed) in mm
# per second, we find that
#
# vel = 0.1*d
#
# In case you haven't figured it out, the * means multiplication.
#
# Now we can use SIMCON to simulate this part of the environment.

# %% [raw]
# Simcon code:
#
# title Fan and Duck
# time 6.0 0.01
# d generator ramp 0.0 6.0 1000.0
# vel amplifier 0 d 0.1 0.5
# plot t vel d
#
# Explanation: (This will help you get used to SIMCON: the definitions are
# in the writeup).
#
# Time: the simulation will run for 6.0 seconds, with the interval between
# computations representing 0.01 seconds. This will lead to 600 data points
# for each plotted variable.
#
# Generator ramp: The disturbing variable d is the output of the "ramp"
# function. It starts at 0.0 sec and ends at 6.0 sec of elapsed time.
# During this time the value of d, the fan blade speed, rises at a uniform
# rate from 0 units to 1000.0 units (RPM). If the plot went on longer, it
# would snap back to 0 after 6.0 seconds. The output of the ramp is d, the
# disturbing variable or fan blade speed. So during this run, the fan blade
# speed rises uniformly from 0 to 1000 RPM.
#
# Amplifier: The output of this amplifier is vel, the velocity of the duck.
# It begins at zero. The input to it is d, the disturbing variable or fan
# blade speed, which is the output of the ramp function. The output is 0.1
# times the input. The time-constant of the amplifier is 0.5 seconds.
#
# "Time constant" refers to how rapidly the output of the amplifier will
# come to the final value of gain * input after a sudden change of the
# input. The output approaches the final value exponentially. The output
# here is "vel", the duck's speed. If the disturbance rises abruptly to
# some value, the duck's speed rises toward 6.0 times the disturbance
# magnitude, reaching about 63% of the final speed after the first 0.5 sec,
# 86% after the next 0.5 second, and so on. We use an amplifier with a time
# constant here to acknowledge the fact that the duck's speed can't change
# instantly: it has some mass.
#
# Plot: This specifies that t is on the x axis and vel and duck are to be
# plotted or on the y axis.

# %%
# << click run

from simcon import *

program1 = """

title Fan and Duck
time 6.0 0.01
d generator ramp 0.0 6.0 1000.0
vel amplifier 0 d 0.1 0.5
plot t vel d

"""
a = AnalogComputer(program1).run().plot()

# %% [markdown]
# You will see a plot of two lines. The one that rises most rapidly is the
# value of the disturbing variable, the fan blade speed in RPM. The other,
# that shows some starting lag, is the duck's speed in mm/sec. The scale
# up the left side applies to both.
#
# Notice that the duck's speed is always about one-tenth of the fan blade's
# speed, each in the appropriate units. It's not quite one tenth because
# there's always a little lag due to the amplifier's time constant and the
# fact that d is changing. We can see what would happen if the fan-blade
# speed simply jumped to some steady value like 1000 RPM instead of rising
# slowly: change the third line of the program from a ramp function to a
# pulse function:
#
# d generator puls 3.0 6.0 1000.0

# %%
program2 = """

title Fan and Duck
time 6.0 0.01
d generator ramp 0.0 6.0 1000.0    <<< change and click run
vel amplifier 0 d 0.1 0.5
plot t vel d

"""
a = AnalogComputer(program2).run().plot()

# %% [markdown]
# Explanation: d starts from zero, then at an elapsed time of 3 seconds
# jumps to 1000.0. At 6 seconds it returns to zero (but that's the end of
# the plot).

# %% [markdown]
# Now when you run the program, you'll see that the velocity of the duck
# rises to 100.0 mm/sec along a curve that levels out after a few seconds.
#
# In interpreting this plot, you have to keep in mind what the y-position
# of a dot indicates. The duck plot shows velocity. So in this last plot,
# when the line representing the duck levels out, this doesn't mean that
# the duck has reached a steady position. It means that the duck is now
# drifting across the swimming pool at a constant speed. The rising curve
# shows that this speed starts at zero and then rises: the duck is
# accelerating until the velocity levels out.
#
# All the variables in an analog simulation are plotted in the same way,
# as a vertical position that changes with time (the horizontal dimension).
# Unless you label the plots, there's no way to tell what they mean in
# terms of the physical situation. When you look at the upper plot,
# something in your head has to whisper ("That's RPM, the fan blade speed."
# When you look at the lower plot, the whisper has to say "That's how fast
# the duck is moving."
#
# Later on, when we talk about perceptions, this will come to have
# considerable significance. A hint: all neural signals are alike, and can
# change only in magnitude.
#
#               Expanding the environmental model
#
# Our putative controlled variable, vel, is affected right now by only one
# other variable, d. We need to provide a physical way for the output of
# a control system also to affect vel. The output will be some physical
# variable like a force, or some other variable that directly depends on
# the output of the control system and on nothing else. Let's call this
# physical variable the output variable, o. The lower-case o should cause
# no confusion with zero.
#
# At a cost of $250, we install a small motor and reversible propeller in
# the duck, with a radio-control receiver that can vary the speed of the
# propellor. Beside the swimming pool we have the transmitter with a speed
# control knob on it. The angle of this speed control knob from the zero
# center mark is the output variable o. By setting o to various angles,
# positive or negative and measured in degrees, we can determine the
# corresponding velocity of the duck through the water with the fan off.
# This relationship proves, conveniently, to be
#
# vel(mm/sec) = 0.5*o(deg)
#
# With both the fan and the radio-controlled propeller working, the
# velocity of the duck turns out to be
#
# vel = 0.1*d + 0.5*o
#
# If the duck is to be stationary, meaning vel = 0, it's clear that the
# propeller must be run in reverse to create a negative component that just
# cancels the positive effect of the fan. If the fan is going at 500 RPM,
# the effect on the duck is 50 units of something; to have -50 units of
# effect, the control knob must be set to -100 degrees.
#
# We can now modify our computing setup to include the effect of the output
# variable o.
#
# -------------------------------------------------------------
# title Fan and Duck
# time 6.0 0.01
# d generator ramp 0.0 6.0 1000.0
# o generator puls 2.0 4.0 -120.0
# effect summator d 0.1 o 0.5
# vel amplifier effect 0.0 1.0 0.5
# print vel d
# plot
#
# Explanation: The disturbing variable follows a ramp function as in the
# initial program. The output of the pulse function, o, is zero except
# between 2.0 and 4.0 seconds of elapsed time, when it is -100 (degrees).
# The net effect on the duck is the output of a summator, which receives
# both d and o with weights of 0.1 and 0.5. The total effect is then the
# input to the amplifier that yields the duck's velocity at its output. The
# gain of the amplifier is now 1.0.
# ---------------------------------------------------------------
#
# The velocity of the duck, vel,  now begins to rise along with the rise
# in fan speed, d. When the negative pulse of propellor speed begins,
# however, as the control knob is abruptly turned to -120 degrees, the
# duck's speed declines and goes negative (i.e., moves for a while in the
# opposite direction). The continually-increasing fan speed soon causes the
# duck to come back to rest and then begin move faster and faster to the
# west. When the remote control knob is suddenly turned back to zero, so
# the propeller stops, the duck's speed quickly picks up to where it should
# be with the fan alone operating.
#
# In the next installment of the series, we will add a control system to
# the simulation.
